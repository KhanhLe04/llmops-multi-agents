# %%
# Đợi vài phút để PyPI cập nhật
# !pip install --upgrade protonx
# !pip install python-dotenv
# !pip install requests
# !pip install matplotlib
# !pip install pandas
# !pip install datasets
# !pip install langchain-google-genai==2.1.9
# Out:
# Requirement already satisfied: protonx in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (0.1.6)
# Requirement already satisfied: requests>=2.31.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from protonx) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from requests>=2.31.0->protonx) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from requests>=2.31.0->protonx) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from requests>=2.31.0->protonx) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from requests>=2.31.0->protonx) (2025.10.5)
# Requirement already satisfied: python-dotenv in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (1.2.1)
# Requirement already satisfied: requests in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from requests) (2025.10.5)
# Requirement already satisfied: matplotlib in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from matplotlib) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: pandas in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.23.2 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: datasets in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (4.4.1)
# Requirement already satisfied: filelock in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from datasets) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from datasets) (2.3.4)
# Requirement already satisfied: pyarrow>=21.0.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from datasets) (0.70.18)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2025.10.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from datasets) (1.1.2)
# Requirement already satisfied: packaging in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: anyio in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from httpx<1.0.0->datasets) (4.11.0)
# Requirement already satisfied: certifi in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from httpx<1.0.0->datasets) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.2.0)
# Requirement already satisfied: shellingham in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.5.4)
# Requirement already satisfied: typer-slim in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: colorama in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: click>=8.0.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (8.3.0)
# Requirement already satisfied: langchain-google-genai==2.1.9 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (2.1.9)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from langchain-google-genai==2.1.9) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<0.7.0,>=0.6.18 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from langchain-google-genai==2.1.9) (0.6.18)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.68 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from langchain-google-genai==2.1.9) (0.3.79)
# Requirement already satisfied: pydantic<3,>=2 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from langchain-google-genai==2.1.9) (2.12.4)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (2.28.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (2.43.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (6.33.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (1.72.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (2.32.5)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (1.76.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (4.9.1)
# Requirement already satisfied: typing-extensions~=4.12 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from grpcio<2.0.0,>=1.33.2->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (4.15.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai==2.1.9) (0.4.42)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai==2.1.9) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai==2.1.9) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai==2.1.9) (6.0.3)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai==2.1.9) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<0.4.0,>=0.3.68->langchain-google-genai==2.1.9) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai==2.1.9) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai==2.1.9) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai==2.1.9) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai==2.1.9) (0.25.0)
# Requirement already satisfied: anyio in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai==2.1.9) (4.11.0)
# Requirement already satisfied: certifi in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai==2.1.9) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai==2.1.9) (1.0.9)
# Requirement already satisfied: idna in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai==2.1.9) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai==2.1.9) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from pydantic<3,>=2->langchain-google-genai==2.1.9) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from pydantic<3,>=2->langchain-google-genai==2.1.9) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from pydantic<3,>=2->langchain-google-genai==2.1.9) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai==2.1.9) (0.6.1)
# Requirement already satisfied: sniffio>=1.1 in d:\docs\uit\kltn\llmops-multi-agents\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai==2.1.9) (1.3.1)

# %%
# %run build_eval_dataset.py --raw-file raw_qa.txt --output-file eval_dataset.json --orchestrator-url http://localhost:7010 --sleep 5
# Out:
# INFO:root:Processing Q1: Stress có thể biểu hiện như thế nào về mặt cảm xúc...
# INFO:root:Received response for Q1
# INFO:root:Processing Q2: Stress ảnh hưởng như thế nào đến hành vi?...
# INFO:root:Received response for Q2
# INFO:root:Processing Q3: Stress có phải lúc nào cũng xấu không?...
# INFO:root:Received response for Q3
# INFO:root:Processing Q4: Khi bị stress, cơ thể thường có phản ứng ra sao?...
# INFO:root:Received response for Q4
# INFO:root:Processing Q5: Sinh viên thường bị stress trong những tình huống ...
# INFO:root:Received response for Q5
# INFO:root:Processing Q6: Làm thế nào để phòng ngừa và kiểm soát stress hiệu...
# INFO:root:Received response for Q6
# INFO:root:Processing Q7: Lo âu là gì?...
# INFO:root:Received response for Q7
# INFO:root:Processing Q8: Lo âu có thể xuất phát từ đâu?...
# INFO:root:Received response for Q8
# INFO:root:Processing Q9: Người bị lo âu thường có những biểu hiện tâm lý nà...
# INFO:root:Received response for Q9
# INFO:root:Processing Q10: Khi bị lo âu, cơ thể thường phản ứng ra sao?...
# INFO:root:Received response for Q10
# [OK] Saved evaluation dataset: eval_dataset.json (samples=10)

# %%
from protonx import ProtonX

# %%
import protonx
protonx.__version__
# Out:
# '0.1.6'

# %% [markdown]
# #### Bạn hãy lấy Access Token của mình [ở đây](https://platform.protonx.io/).
# #### Set API Key: PROTONX_API_KEY=api_key

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
client = ProtonX()

# %% [markdown]
# ## Kiểm tra tính chính xác của chatbot

# %% [markdown]
# Điểm liên quan tới chất lượng trả lời
# - Precision
# - Recall
# - F1

# %%
metrics = ["precision", "recall", "f1"]

# %%
import json
from pathlib import Path

dataset_path = Path("eval_dataset.json")
data = json.loads(dataset_path.read_text(encoding="utf-8"))
data[:3]
# Out:
# [{'question': 'Stress có thể biểu hiện như thế nào về mặt cảm xúc?',
#   'ground_truth': 'Stress thường biểu hiện rõ rệt qua những thay đổi về mặt cảm xúc. Người đang chịu căng thẳng có thể cảm thấy khó chịu, bực bội hoặc dễ cáu gắt mà không rõ lý do. Họ thường xuyên lo lắng, bất an, luôn trong trạng thái căng thẳng. Nhiều người rơi vào cảm giác buồn bã, chán nản, mất hứng thú với những điều từng yêu thích. Ở mức độ cao hơn, stress còn khiến họ cảm thấy thờ ơ với mọi thứ xung quanh, mất niềm tin vào bản thân và cảm giác như đánh mất giá trị của chính mình.',
#   'answer': 'Chào bạn,\n\nBạn đang thắc mắc về việc stress có thể biểu hiện như thế nào về mặt cảm xúc đúng không? Mình hiểu rằng đôi khi những cảm xúc tiêu cực có thể khiến chúng ta cảm thấy khó khăn và bối rối. \n\nVề mặt cảm xúc, stress có thể hiện ra rất nhiều cách khác nhau, có thể khiến bạn cảm thấy:\n\n*   **Khó chịu:** Cảm giác bực bội, khó chịu, dễ cáu gắt hơn bình thường.\n*   **Lo lắng, căng thẳng:** Luôn cảm thấy bồn chồn, lo lắng về những việc sắp tới hoặc những vấn đề đang gặp phải.\n*   **Buồn bã, chán nản:** Mất hứng thú với những việc mình từng yêu thích, cảm thấy mọi thứ trở nên vô vị.\n*   **Mất giá trị bản thân:** Cảm thấy mình không đủ tốt, không có giá trị, dễ tự ti.\n\nNgoài ra, stress còn có thể khiến bạn dễ nổi nóng, trở nên nóng tính hơn, hoặc thậm chí là cảm thấy mất mát, trống rỗng. \n\nViệc nhận biết những biểu hiện cảm xúc này là bước đầu tiên rất quan trọng để đối diện với stress. Hãy thử dành thời gian lắng nghe cảm xúc của mình, chấp nhận rằng việc cảm thấy tiêu cực là điều bình thường khi phải đối mặt với áp lực.\n\nNếu bạn cảm thấy những cảm xúc này quá mạnh mẽ và ảnh hưởng đến cuộc sống của mình, đừng ngần ngại tìm kiếm sự giúp đỡ từ bạn bè, người thân hoặc chuyên gia tâm lý nhé. Mình luôn ở đây để lắng nghe và hỗ trợ bạn.\n\n**Nếu bạn đang trong tình trạng khủng hoảng hoặc có ý định làm hại bản thân, hãy liên hệ ngay với người thân, bạn bè hoặc chuyên gia tâm lý tại trường. Bạn không đơn độc và có người sẵn sàng giúp đỡ.**',
#   'contexts': ['USSH_VaccineTinhThan_SoTay_ChamSoc_SKTT_SinhVien_vi.pdf',
#    'MOET_UNICEF_TaiLieu_TruyenThong_SKTT_HS_PhoThong_vi_2023.pdf'],
#   'metadata': {'selected_agent': 'RAG Agent',
#    'raw_response': {'selected_agent': 'RAG Agent',
#     'response': 'Chào bạn,\n\nBạn đang thắc mắc về việc stress có thể biểu hiện như thế nào về mặt cảm xúc đúng không? Mình hiểu rằng đôi khi những cảm xúc tiêu cực có thể khiến chúng ta cảm thấy khó khăn và bối rối. \n\nVề mặt cảm xúc, stress có thể hiện ra rất nhiều cách khác nhau, có thể khiến bạn cảm thấy:\n\n*   **Khó chịu:** Cảm giác bực bội, khó chịu, dễ cáu gắt hơn bình thường.\n*   **Lo lắng, căng thẳng:** Luôn cảm thấy bồn chồn, lo lắng về những việc sắp tới hoặc những vấn đề đang gặp phải.\n*   **Buồn bã, chán nản:** Mất hứng thú với những việc mình từng yêu thích, cảm thấy mọi thứ trở nên vô vị.\n*   **Mất giá trị bản thân:** Cảm thấy mình không đủ tốt, không có giá trị, dễ tự ti.\n\nNgoài ra, stress còn có thể khiến bạn dễ nổi nóng, trở nên nóng tính hơn, hoặc thậm chí là cảm thấy mất mát, trống rỗng. \n\nViệc nhận biết những biểu hiện cảm xúc này là bước đầu tiên rất quan trọng để đối diện với stress. Hãy thử dành thời gian lắng nghe cảm xúc của mình, chấp nhận rằng việc cảm thấy tiêu cực là điều bình thường khi phải đối mặt với áp lực.\n\nNếu bạn cảm thấy những cảm xúc này quá mạnh mẽ và ảnh hưởng đến cuộc sống của mình, đừng ngần ngại tìm kiếm sự giúp đỡ từ bạn bè, người thân hoặc chuyên gia tâm lý nhé. Mình luôn ở đây để lắng nghe và hỗ trợ bạn.\n\n**Nếu bạn đang trong tình trạng khủng hoảng hoặc có ý định làm hại bản thân, hãy liên hệ ngay với người thân, bạn bè hoặc chuyên gia tâm lý tại trường. Bạn không đơn độc và có người sẵn sàng giúp đỡ.**\n',
#     'sources': ['USSH_VaccineTinhThan_SoTay_ChamSoc_SKTT_SinhVien_vi.pdf',
#      'MOET_UNICEF_TaiLieu_TruyenThong_SKTT_HS_PhoThong_vi_2023.pdf'],
#     'error': None}}},
#  {'question': 'Stress ảnh hưởng như thế nào đến hành vi?',
#   'ground_truth': 'Stress có thể tác động mạnh mẽ đến hành vi của con người, khiến họ thay đổi cách ứng xử trong cuộc sống hằng ngày. Một người đang chịu căng thẳng thường dễ nổi cáu, bực bội hoặc trở nên nóng nảy hơn bình thường. Họ có xu hướng tìm đến các chất kích thích như rượu, thuốc lá để giải tỏa tạm thời. Các thói quen sinh hoạt cũng dễ bị xáo trộn — ăn uống thất thường, mất ngủ hoặc ngủ quá nhiều. Ngoài ra, stress còn khiến con người mất tập trung, hay quên, đưa ra những quyết định thiếu lý trí, hành động vội vàng, hấp tấp, thậm chí trở nên vụng về trong công việc và cuộc sống.',
#   'answer': 'Chào bạn,\n\nBạn đang thắc mắc về việc stress ảnh hưởng đến hành vi như thế nào đúng không? Đây là một câu hỏi rất hay và quan trọng. Mình hiểu rằng đôi khi stress có thể khiến chúng ta cảm thấy khó khăn trong việc kiểm soát bản thân và hành động theo những cách không mong muốn.\n\nHãy hình dung stress giống như một "cảnh báo" của cơ thể. Khi chúng ta đối mặt với những áp lực, khó khăn (ví dụ như áp lực học tập, các mối quan hệ, hoặc những thay đổi trong cuộc sống), cơ thể sẽ phản ứng bằng cách giải phóng các hormone stress. Điều này giúp chúng ta có thêm năng lượng để đối phó với tình huống đó.\n\nTuy nhiên, nếu stress kéo dài hoặc quá mức, nó có thể tác động tiêu cực đến nhiều khía cạnh trong cuộc sống của bạn, cụ thể như:\n\n*   **Về cảm xúc:** Bạn có thể cảm thấy dễ cáu gắt, lo lắng, buồn bã, thậm chí là mất hứng thú với những điều mình từng yêu thích. Đôi khi, bạn có thể cảm thấy mình không đủ tốt, vô dụng hoặc thất bại.\n*   **Về hành vi:** Stress có thể khiến bạn thay đổi thói quen ăn uống, ngủ nghỉ. Có người lại tìm đến các chất kích thích như rượu, thuốc lá để giải tỏa. Một số người lại trở nên bồn chồn, khó tập trung, hoặc thậm chí là thu mình lại, tránh giao tiếp với mọi người.\n*   **Về học tập:** Stress có thể ảnh hưởng đến khả năng tập trung, ghi nhớ, và làm bài tập. Bạn có thể cảm thấy mất động lực học tập, không còn hứng thú với việc học.\n*   **Về các mối quan hệ:** Stress có thể khiến bạn dễ xung đột với bạn bè, gia đình, hoặc những người xung quanh. Bạn có thể trở nên khó chịu, cáu gắt, hoặc thậm chí là xa lánh mọi người.\n\nĐiều quan trọng là bạn cần nhận biết những dấu hiệu stress đang ảnh hưởng đến mình. Đừng cố gắng gồng mình lên để đối phó một mình. Hãy tìm kiếm sự hỗ trợ từ những người xung quanh, như gia đình, bạn bè, thầy cô, hoặc chuyên gia tâm lý.\n\n**Một vài gợi ý nhỏ có thể giúp bạn đối diện với stress:**\n\n*   **Tìm hiểu nguyên nhân:** Hãy thử xác định xem điều gì đang gây ra stress cho bạn. Khi đã biết nguyên nhân, bạn có thể tìm cách giải quyết hoặc giảm bớt áp lực.\n*   **Chăm sóc bản thân:** Đảm bảo bạn có đủ giấc ngủ, ăn uống đầy đủ, và tập thể dục thường xuyên. Những hoạt động này có thể giúp bạn giảm căng thẳng và cải thiện tâm trạng.\n*   **Tìm kiếm hoạt động thư giãn:** Hãy dành thời gian cho những hoạt động mà bạn yêu thích, như nghe nhạc, đọc sách, xem phim, hoặc đi dạo.\n*   **Chia sẻ với người khác:** Đừng ngại chia sẻ những cảm xúc của bạn với những người bạn tin tưởng. Việc được lắng nghe và thấu hiểu có thể giúp bạn cảm thấy tốt hơn.\n*   **Học cách quản lý thời gian:** Lập kế hoạch học tập và làm việc một cách khoa học để tránh bị quá tải.\n\nNếu bạn cảm thấy quá khó khăn để đối phó với stress, hoặc nếu bạn có những ý nghĩ tiêu cực về bản thân, đừng ngần ngại tìm kiếm sự giúp đỡ từ chuyên gia tâm lý nhé. Họ có thể cung cấp cho bạn những công cụ và kỹ thuật để quản lý stress một cách hiệu quả.\n\n**Nếu em đang trong tình trạng khủng hoảng hoặc có ý định làm hại bản thân, hãy liên hệ ngay với người thân, bạn bè hoặc chuyên gia tâm lý tại trường. Em không đơn độc và có người sẵn sàng giúp đỡ.**\n\nMình luôn ở đây để lắng nghe và hỗ trợ bạn. Hãy nhớ rằng bạn xứng đáng được hạnh phúc và có một cuộc sống khỏe mạnh về tinh thần.',
#   'contexts': ['USSH_VaccineTinhThan_SoTay_ChamSoc_SKTT_SinhVien_vi.pdf',
#    'MOET_UNICEF_SoTay_TuVan_TamLy_HS_PhoThong_vi_2022.pdf',
#    'MOET_UNICEF_TaiLieu_TruyenThong_SKTT_HS_PhoThong_vi_2023.pdf'],
#   'metadata': {'selected_agent': 'RAG Agent',
#    'raw_response': {'selected_agent': 'RAG Agent',
#     'response': 'Chào bạn,\n\nBạn đang thắc mắc về việc stress ảnh hưởng đến hành vi như thế nào đúng không? Đây là một câu hỏi rất hay và quan trọng. Mình hiểu rằng đôi khi stress có thể khiến chúng ta cảm thấy khó khăn trong việc kiểm soát bản thân và hành động theo những cách không mong muốn.\n\nHãy hình dung stress giống như một "cảnh báo" của cơ thể. Khi chúng ta đối mặt với những áp lực, khó khăn (ví dụ như áp lực học tập, các mối quan hệ, hoặc những thay đổi trong cuộc sống), cơ thể sẽ phản ứng bằng cách giải phóng các hormone stress. Điều này giúp chúng ta có thêm năng lượng để đối phó với tình huống đó.\n\nTuy nhiên, nếu stress kéo dài hoặc quá mức, nó có thể tác động tiêu cực đến nhiều khía cạnh trong cuộc sống của bạn, cụ thể như:\n\n*   **Về cảm xúc:** Bạn có thể cảm thấy dễ cáu gắt, lo lắng, buồn bã, thậm chí là mất hứng thú với những điều mình từng yêu thích. Đôi khi, bạn có thể cảm thấy mình không đủ tốt, vô dụng hoặc thất bại.\n*   **Về hành vi:** Stress có thể khiến bạn thay đổi thói quen ăn uống, ngủ nghỉ. Có người lại tìm đến các chất kích thích như rượu, thuốc lá để giải tỏa. Một số người lại trở nên bồn chồn, khó tập trung, hoặc thậm chí là thu mình lại, tránh giao tiếp với mọi người.\n*   **Về học tập:** Stress có thể ảnh hưởng đến khả năng tập trung, ghi nhớ, và làm bài tập. Bạn có thể cảm thấy mất động lực học tập, không còn hứng thú với việc học.\n*   **Về các mối quan hệ:** Stress có thể khiến bạn dễ xung đột với bạn bè, gia đình, hoặc những người xung quanh. Bạn có thể trở nên khó chịu, cáu gắt, hoặc thậm chí là xa lánh mọi người.\n\nĐiều quan trọng là bạn cần nhận biết những dấu hiệu stress đang ảnh hưởng đến mình. Đừng cố gắng gồng mình lên để đối phó một mình. Hãy tìm kiếm sự hỗ trợ từ những người xung quanh, như gia đình, bạn bè, thầy cô, hoặc chuyên gia tâm lý.\n\n**Một vài gợi ý nhỏ có thể giúp bạn đối diện với stress:**\n\n*   **Tìm hiểu nguyên nhân:** Hãy thử xác định xem điều gì đang gây ra stress cho bạn. Khi đã biết nguyên nhân, bạn có thể tìm cách giải quyết hoặc giảm bớt áp lực.\n*   **Chăm sóc bản thân:** Đảm bảo bạn có đủ giấc ngủ, ăn uống đầy đủ, và tập thể dục thường xuyên. Những hoạt động này có thể giúp bạn giảm căng thẳng và cải thiện tâm trạng.\n*   **Tìm kiếm hoạt động thư giãn:** Hãy dành thời gian cho những hoạt động mà bạn yêu thích, như nghe nhạc, đọc sách, xem phim, hoặc đi dạo.\n*   **Chia sẻ với người khác:** Đừng ngại chia sẻ những cảm xúc của bạn với những người bạn tin tưởng. Việc được lắng nghe và thấu hiểu có thể giúp bạn cảm thấy tốt hơn.\n*   **Học cách quản lý thời gian:** Lập kế hoạch học tập và làm việc một cách khoa học để tránh bị quá tải.\n\nNếu bạn cảm thấy quá khó khăn để đối phó với stress, hoặc nếu bạn có những ý nghĩ tiêu cực về bản thân, đừng ngần ngại tìm kiếm sự giúp đỡ từ chuyên gia tâm lý nhé. Họ có thể cung cấp cho bạn những công cụ và kỹ thuật để quản lý stress một cách hiệu quả.\n\n**Nếu em đang trong tình trạng khủng hoảng hoặc có ý định làm hại bản thân, hãy liên hệ ngay với người thân, bạn bè hoặc chuyên gia tâm lý tại trường. Em không đơn độc và có người sẵn sàng giúp đỡ.**\n\nMình luôn ở đây để lắng nghe và hỗ trợ bạn. Hãy nhớ rằng bạn xứng đáng được hạnh phúc và có một cuộc sống khỏe mạnh về tinh thần.\n',
#     'sources': ['USSH_VaccineTinhThan_SoTay_ChamSoc_SKTT_SinhVien_vi.pdf',
#      'MOET_UNICEF_SoTay_TuVan_TamLy_HS_PhoThong_vi_2022.pdf',
#      'MOET_UNICEF_TaiLieu_TruyenThong_SKTT_HS_PhoThong_vi_2023.pdf'],
#     'error': None}}},
#  {'question': 'Stress có phải lúc nào cũng xấu không?',
#   'ground_truth': 'Stress không phải lúc nào cũng là điều tiêu cực. Thực tế, mỗi người đều có thể trải qua stress ở một thời điểm nào đó trong cuộc sống — đôi khi chỉ trong thời gian ngắn, đôi khi kéo dài hoặc lặp đi lặp lại. Ở mức độ vừa phải, stress có thể đóng vai trò tích cực, giúp con người có thêm động lực, tập trung và thích nghi tốt hơn với thử thách. Tuy nhiên, khi stress trở nên quá mức và kéo dài vượt quá khả năng kiểm soát của bản thân, nó sẽ gây ra những tác động tiêu cực đến sức khỏe. Cụ thể, stress mãn tính có thể dẫn đến các bệnh lý như tim mạch, tăng huyết áp, tiểu đường, cũng như các rối loạn tâm lý như lo âu hoặc trầm cảm.',
#   'answer': 'Chào bạn, câu hỏi của bạn rất hay và cũng là điều mà nhiều người thắc mắc đấy. Mình hiểu rằng đôi khi stress nghe có vẻ tiêu cực, nhưng thực tế nó không phải lúc nào cũng vậy đâu.\n\nHãy tưởng tượng stress giống như một "cảnh báo" từ cơ thể của chúng ta. Khi gặp phải những tình huống mới, khó khăn hoặc áp lực, cơ thể sẽ sản sinh ra stress để giúp chúng ta tập trung hơn, có động lực để đối phó và giải quyết vấn đề. Ví dụ, trước một bài kiểm tra quan trọng, một chút stress có thể giúp bạn ôn tập kỹ hơn và làm bài tốt hơn đấy!\n\nTuy nhiên, vấn đề nằm ở chỗ khi stress trở nên quá mức và kéo dài, hoặc khi chúng ta không có cách nào để giải tỏa nó, thì lúc này stress mới trở nên tiêu cực. Nó có thể ảnh hưởng đến tâm trạng, sức khỏe thể chất và cả các mối quan hệ của bạn. Bạn có thể cảm thấy khó chịu, lo lắng, mất ngủ, hoặc thậm chí là không còn hứng thú với những việc mình từng yêu thích nữa.\n\nVậy làm thế nào để đối diện với stress một cách lành mạnh?\n\n*   **Nhận biết dấu hiệu:** Hãy chú ý đến những thay đổi trong cảm xúc, suy nghĩ và hành vi của mình. Khi cảm thấy căng thẳng, đừng cố gắng phớt lờ nó.\n*   **Tìm hiểu nguyên nhân:** Cố gắng xác định điều gì đang gây ra stress cho bạn. Có thể là áp lực học tập, vấn đề trong gia đình, hoặc những khó khăn trong cuộc sống.\n*   **Tìm cách giải tỏa:** Có rất nhiều cách để giải tỏa stress, như tập thể dục, nghe nhạc, đọc sách, trò chuyện với bạn bè hoặc người thân, hoặc đơn giản là dành thời gian cho những sở thích cá nhân.\n*   **Học cách thư giãn:** Các bài tập thở, thiền, yoga có thể giúp bạn giảm căng thẳng và tìm lại sự bình tĩnh.\n*   **Chia sẻ:** Đừng ngại chia sẻ những khó khăn của mình với người mà bạn tin tưởng. Đôi khi, chỉ cần nói ra những điều mình đang trải qua cũng có thể giúp bạn cảm thấy tốt hơn.\n\nNếu bạn cảm thấy stress đang ảnh hưởng nghiêm trọng đến cuộc sống của mình, đừng ngần ngại tìm kiếm sự giúp đỡ từ chuyên gia tâm lý nhé. Họ có thể cung cấp cho bạn những lời khuyên và hỗ trợ phù hợp.\n\n**Nếu em đang trong tình trạng khủng hoảng hoặc có ý định làm hại bản thân, hãy liên hệ ngay với người thân, bạn bè hoặc chuyên gia tâm lý tại trường. Em không đơn độc và có người sẵn sàng giúp đỡ.**\n\nMình luôn ở đây để lắng nghe và hỗ trợ bạn. Đừng ngần ngại chia sẻ bất cứ điều gì bạn đang gặp phải nhé!',
#   'contexts': ['USSH_VaccineTinhThan_SoTay_ChamSoc_SKTT_SinhVien_vi.pdf',
#    'MOET_UNICEF_TaiLieu_TruyenThong_SKTT_HS_PhoThong_vi_2023.pdf'],
#   'metadata': {'selected_agent': 'RAG Agent',
#    'raw_response': {'selected_agent': 'RAG Agent',
#     'response': 'Chào bạn, câu hỏi của bạn rất hay và cũng là điều mà nhiều người thắc mắc đấy. Mình hiểu rằng đôi khi stress nghe có vẻ tiêu cực, nhưng thực tế nó không phải lúc nào cũng vậy đâu.\n\nHãy tưởng tượng stress giống như một "cảnh báo" từ cơ thể của chúng ta. Khi gặp phải những tình huống mới, khó khăn hoặc áp lực, cơ thể sẽ sản sinh ra stress để giúp chúng ta tập trung hơn, có động lực để đối phó và giải quyết vấn đề. Ví dụ, trước một bài kiểm tra quan trọng, một chút stress có thể giúp bạn ôn tập kỹ hơn và làm bài tốt hơn đấy!\n\nTuy nhiên, vấn đề nằm ở chỗ khi stress trở nên quá mức và kéo dài, hoặc khi chúng ta không có cách nào để giải tỏa nó, thì lúc này stress mới trở nên tiêu cực. Nó có thể ảnh hưởng đến tâm trạng, sức khỏe thể chất và cả các mối quan hệ của bạn. Bạn có thể cảm thấy khó chịu, lo lắng, mất ngủ, hoặc thậm chí là không còn hứng thú với những việc mình từng yêu thích nữa.\n\nVậy làm thế nào để đối diện với stress một cách lành mạnh?\n\n*   **Nhận biết dấu hiệu:** Hãy chú ý đến những thay đổi trong cảm xúc, suy nghĩ và hành vi của mình. Khi cảm thấy căng thẳng, đừng cố gắng phớt lờ nó.\n*   **Tìm hiểu nguyên nhân:** Cố gắng xác định điều gì đang gây ra stress cho bạn. Có thể là áp lực học tập, vấn đề trong gia đình, hoặc những khó khăn trong cuộc sống.\n*   **Tìm cách giải tỏa:** Có rất nhiều cách để giải tỏa stress, như tập thể dục, nghe nhạc, đọc sách, trò chuyện với bạn bè hoặc người thân, hoặc đơn giản là dành thời gian cho những sở thích cá nhân.\n*   **Học cách thư giãn:** Các bài tập thở, thiền, yoga có thể giúp bạn giảm căng thẳng và tìm lại sự bình tĩnh.\n*   **Chia sẻ:** Đừng ngại chia sẻ những khó khăn của mình với người mà bạn tin tưởng. Đôi khi, chỉ cần nói ra những điều mình đang trải qua cũng có thể giúp bạn cảm thấy tốt hơn.\n\nNếu bạn cảm thấy stress đang ảnh hưởng nghiêm trọng đến cuộc sống của mình, đừng ngần ngại tìm kiếm sự giúp đỡ từ chuyên gia tâm lý nhé. Họ có thể cung cấp cho bạn những lời khuyên và hỗ trợ phù hợp.\n\n**Nếu em đang trong tình trạng khủng hoảng hoặc có ý định làm hại bản thân, hãy liên hệ ngay với người thân, bạn bè hoặc chuyên gia tâm lý tại trường. Em không đơn độc và có người sẵn sàng giúp đỡ.**\n\nMình luôn ở đây để lắng nghe và hỗ trợ bạn. Đừng ngần ngại chia sẻ bất cứ điều gì bạn đang gặp phải nhé!\n',
#     'sources': ['USSH_VaccineTinhThan_SoTay_ChamSoc_SKTT_SinhVien_vi.pdf',
#      'MOET_UNICEF_TaiLieu_TruyenThong_SKTT_HS_PhoThong_vi_2023.pdf'],
#     'error': None}}}]

# %% [markdown]
# Câu hỏi mà bạn đưa vào Chatbot của bạn

# %%
questions = [sample["question"] for sample in data]  # nếu dùng protonx_dataset
# hoặc nếu dùng eval_dataset.json (chưa map):
# questions = [sample["question"] for sample in data]

questions[:3]
# Out:
# ['Stress có thể biểu hiện như thế nào về mặt cảm xúc?',
#  'Stress ảnh hưởng như thế nào đến hành vi?',
#  'Stress có phải lúc nào cũng xấu không?']

# %% [markdown]
# Câu trả lời bạn kỳ vọng chatbot sẽ trả lời

# %%
ground_truths = [sample["ground_truth"] for sample in data]

len(ground_truths), ground_truths[:3]
# Out:
# (10,
#  ['Stress thường biểu hiện rõ rệt qua những thay đổi về mặt cảm xúc. Người đang chịu căng thẳng có thể cảm thấy khó chịu, bực bội hoặc dễ cáu gắt mà không rõ lý do. Họ thường xuyên lo lắng, bất an, luôn trong trạng thái căng thẳng. Nhiều người rơi vào cảm giác buồn bã, chán nản, mất hứng thú với những điều từng yêu thích. Ở mức độ cao hơn, stress còn khiến họ cảm thấy thờ ơ với mọi thứ xung quanh, mất niềm tin vào bản thân và cảm giác như đánh mất giá trị của chính mình.',
#   'Stress có thể tác động mạnh mẽ đến hành vi của con người, khiến họ thay đổi cách ứng xử trong cuộc sống hằng ngày. Một người đang chịu căng thẳng thường dễ nổi cáu, bực bội hoặc trở nên nóng nảy hơn bình thường. Họ có xu hướng tìm đến các chất kích thích như rượu, thuốc lá để giải tỏa tạm thời. Các thói quen sinh hoạt cũng dễ bị xáo trộn — ăn uống thất thường, mất ngủ hoặc ngủ quá nhiều. Ngoài ra, stress còn khiến con người mất tập trung, hay quên, đưa ra những quyết định thiếu lý trí, hành động vội vàng, hấp tấp, thậm chí trở nên vụng về trong công việc và cuộc sống.',
#   'Stress không phải lúc nào cũng là điều tiêu cực. Thực tế, mỗi người đều có thể trải qua stress ở một thời điểm nào đó trong cuộc sống — đôi khi chỉ trong thời gian ngắn, đôi khi kéo dài hoặc lặp đi lặp lại. Ở mức độ vừa phải, stress có thể đóng vai trò tích cực, giúp con người có thêm động lực, tập trung và thích nghi tốt hơn với thử thách. Tuy nhiên, khi stress trở nên quá mức và kéo dài vượt quá khả năng kiểm soát của bản thân, nó sẽ gây ra những tác động tiêu cực đến sức khỏe. Cụ thể, stress mãn tính có thể dẫn đến các bệnh lý như tim mạch, tăng huyết áp, tiểu đường, cũng như các rối loạn tâm lý như lo âu hoặc trầm cảm.'])

# %% [markdown]
# Ngữ cảnh chatbot dùng để trả lời

# %%
contexts = [sample["answer"] for sample in data]

len(contexts), contexts[:3]
# Out:
# (10,
#  ['Chào bạn,\n\nBạn đang thắc mắc về việc stress có thể biểu hiện như thế nào về mặt cảm xúc đúng không? Mình hiểu rằng đôi khi những cảm xúc tiêu cực có thể khiến chúng ta cảm thấy khó khăn và bối rối. \n\nVề mặt cảm xúc, stress có thể hiện ra rất nhiều cách khác nhau, có thể khiến bạn cảm thấy:\n\n*   **Khó chịu:** Cảm giác bực bội, khó chịu, dễ cáu gắt hơn bình thường.\n*   **Lo lắng, căng thẳng:** Luôn cảm thấy bồn chồn, lo lắng về những việc sắp tới hoặc những vấn đề đang gặp phải.\n*   **Buồn bã, chán nản:** Mất hứng thú với những việc mình từng yêu thích, cảm thấy mọi thứ trở nên vô vị.\n*   **Mất giá trị bản thân:** Cảm thấy mình không đủ tốt, không có giá trị, dễ tự ti.\n\nNgoài ra, stress còn có thể khiến bạn dễ nổi nóng, trở nên nóng tính hơn, hoặc thậm chí là cảm thấy mất mát, trống rỗng. \n\nViệc nhận biết những biểu hiện cảm xúc này là bước đầu tiên rất quan trọng để đối diện với stress. Hãy thử dành thời gian lắng nghe cảm xúc của mình, chấp nhận rằng việc cảm thấy tiêu cực là điều bình thường khi phải đối mặt với áp lực.\n\nNếu bạn cảm thấy những cảm xúc này quá mạnh mẽ và ảnh hưởng đến cuộc sống của mình, đừng ngần ngại tìm kiếm sự giúp đỡ từ bạn bè, người thân hoặc chuyên gia tâm lý nhé. Mình luôn ở đây để lắng nghe và hỗ trợ bạn.\n\n**Nếu bạn đang trong tình trạng khủng hoảng hoặc có ý định làm hại bản thân, hãy liên hệ ngay với người thân, bạn bè hoặc chuyên gia tâm lý tại trường. Bạn không đơn độc và có người sẵn sàng giúp đỡ.**',
#   'Chào bạn,\n\nBạn đang thắc mắc về việc stress ảnh hưởng đến hành vi như thế nào đúng không? Đây là một câu hỏi rất hay và quan trọng. Mình hiểu rằng đôi khi stress có thể khiến chúng ta cảm thấy khó khăn trong việc kiểm soát bản thân và hành động theo những cách không mong muốn.\n\nHãy hình dung stress giống như một "cảnh báo" của cơ thể. Khi chúng ta đối mặt với những áp lực, khó khăn (ví dụ như áp lực học tập, các mối quan hệ, hoặc những thay đổi trong cuộc sống), cơ thể sẽ phản ứng bằng cách giải phóng các hormone stress. Điều này giúp chúng ta có thêm năng lượng để đối phó với tình huống đó.\n\nTuy nhiên, nếu stress kéo dài hoặc quá mức, nó có thể tác động tiêu cực đến nhiều khía cạnh trong cuộc sống của bạn, cụ thể như:\n\n*   **Về cảm xúc:** Bạn có thể cảm thấy dễ cáu gắt, lo lắng, buồn bã, thậm chí là mất hứng thú với những điều mình từng yêu thích. Đôi khi, bạn có thể cảm thấy mình không đủ tốt, vô dụng hoặc thất bại.\n*   **Về hành vi:** Stress có thể khiến bạn thay đổi thói quen ăn uống, ngủ nghỉ. Có người lại tìm đến các chất kích thích như rượu, thuốc lá để giải tỏa. Một số người lại trở nên bồn chồn, khó tập trung, hoặc thậm chí là thu mình lại, tránh giao tiếp với mọi người.\n*   **Về học tập:** Stress có thể ảnh hưởng đến khả năng tập trung, ghi nhớ, và làm bài tập. Bạn có thể cảm thấy mất động lực học tập, không còn hứng thú với việc học.\n*   **Về các mối quan hệ:** Stress có thể khiến bạn dễ xung đột với bạn bè, gia đình, hoặc những người xung quanh. Bạn có thể trở nên khó chịu, cáu gắt, hoặc thậm chí là xa lánh mọi người.\n\nĐiều quan trọng là bạn cần nhận biết những dấu hiệu stress đang ảnh hưởng đến mình. Đừng cố gắng gồng mình lên để đối phó một mình. Hãy tìm kiếm sự hỗ trợ từ những người xung quanh, như gia đình, bạn bè, thầy cô, hoặc chuyên gia tâm lý.\n\n**Một vài gợi ý nhỏ có thể giúp bạn đối diện với stress:**\n\n*   **Tìm hiểu nguyên nhân:** Hãy thử xác định xem điều gì đang gây ra stress cho bạn. Khi đã biết nguyên nhân, bạn có thể tìm cách giải quyết hoặc giảm bớt áp lực.\n*   **Chăm sóc bản thân:** Đảm bảo bạn có đủ giấc ngủ, ăn uống đầy đủ, và tập thể dục thường xuyên. Những hoạt động này có thể giúp bạn giảm căng thẳng và cải thiện tâm trạng.\n*   **Tìm kiếm hoạt động thư giãn:** Hãy dành thời gian cho những hoạt động mà bạn yêu thích, như nghe nhạc, đọc sách, xem phim, hoặc đi dạo.\n*   **Chia sẻ với người khác:** Đừng ngại chia sẻ những cảm xúc của bạn với những người bạn tin tưởng. Việc được lắng nghe và thấu hiểu có thể giúp bạn cảm thấy tốt hơn.\n*   **Học cách quản lý thời gian:** Lập kế hoạch học tập và làm việc một cách khoa học để tránh bị quá tải.\n\nNếu bạn cảm thấy quá khó khăn để đối phó với stress, hoặc nếu bạn có những ý nghĩ tiêu cực về bản thân, đừng ngần ngại tìm kiếm sự giúp đỡ từ chuyên gia tâm lý nhé. Họ có thể cung cấp cho bạn những công cụ và kỹ thuật để quản lý stress một cách hiệu quả.\n\n**Nếu em đang trong tình trạng khủng hoảng hoặc có ý định làm hại bản thân, hãy liên hệ ngay với người thân, bạn bè hoặc chuyên gia tâm lý tại trường. Em không đơn độc và có người sẵn sàng giúp đỡ.**\n\nMình luôn ở đây để lắng nghe và hỗ trợ bạn. Hãy nhớ rằng bạn xứng đáng được hạnh phúc và có một cuộc sống khỏe mạnh về tinh thần.',
#   'Chào bạn, câu hỏi của bạn rất hay và cũng là điều mà nhiều người thắc mắc đấy. Mình hiểu rằng đôi khi stress nghe có vẻ tiêu cực, nhưng thực tế nó không phải lúc nào cũng vậy đâu.\n\nHãy tưởng tượng stress giống như một "cảnh báo" từ cơ thể của chúng ta. Khi gặp phải những tình huống mới, khó khăn hoặc áp lực, cơ thể sẽ sản sinh ra stress để giúp chúng ta tập trung hơn, có động lực để đối phó và giải quyết vấn đề. Ví dụ, trước một bài kiểm tra quan trọng, một chút stress có thể giúp bạn ôn tập kỹ hơn và làm bài tốt hơn đấy!\n\nTuy nhiên, vấn đề nằm ở chỗ khi stress trở nên quá mức và kéo dài, hoặc khi chúng ta không có cách nào để giải tỏa nó, thì lúc này stress mới trở nên tiêu cực. Nó có thể ảnh hưởng đến tâm trạng, sức khỏe thể chất và cả các mối quan hệ của bạn. Bạn có thể cảm thấy khó chịu, lo lắng, mất ngủ, hoặc thậm chí là không còn hứng thú với những việc mình từng yêu thích nữa.\n\nVậy làm thế nào để đối diện với stress một cách lành mạnh?\n\n*   **Nhận biết dấu hiệu:** Hãy chú ý đến những thay đổi trong cảm xúc, suy nghĩ và hành vi của mình. Khi cảm thấy căng thẳng, đừng cố gắng phớt lờ nó.\n*   **Tìm hiểu nguyên nhân:** Cố gắng xác định điều gì đang gây ra stress cho bạn. Có thể là áp lực học tập, vấn đề trong gia đình, hoặc những khó khăn trong cuộc sống.\n*   **Tìm cách giải tỏa:** Có rất nhiều cách để giải tỏa stress, như tập thể dục, nghe nhạc, đọc sách, trò chuyện với bạn bè hoặc người thân, hoặc đơn giản là dành thời gian cho những sở thích cá nhân.\n*   **Học cách thư giãn:** Các bài tập thở, thiền, yoga có thể giúp bạn giảm căng thẳng và tìm lại sự bình tĩnh.\n*   **Chia sẻ:** Đừng ngại chia sẻ những khó khăn của mình với người mà bạn tin tưởng. Đôi khi, chỉ cần nói ra những điều mình đang trải qua cũng có thể giúp bạn cảm thấy tốt hơn.\n\nNếu bạn cảm thấy stress đang ảnh hưởng nghiêm trọng đến cuộc sống của mình, đừng ngần ngại tìm kiếm sự giúp đỡ từ chuyên gia tâm lý nhé. Họ có thể cung cấp cho bạn những lời khuyên và hỗ trợ phù hợp.\n\n**Nếu em đang trong tình trạng khủng hoảng hoặc có ý định làm hại bản thân, hãy liên hệ ngay với người thân, bạn bè hoặc chuyên gia tâm lý tại trường. Em không đơn độc và có người sẵn sàng giúp đỡ.**\n\nMình luôn ở đây để lắng nghe và hỗ trợ bạn. Đừng ngần ngại chia sẻ bất cứ điều gì bạn đang gặp phải nhé!'])

# %% [markdown]
# Câu trả lời thực tế của Chatbot

# %%
response_llms = [sample["answer"] for sample in data]

len(response_llms), response_llms[:3]
# Out:
# (10,
#  ['Chào bạn,\n\nBạn đang thắc mắc về việc stress có thể biểu hiện như thế nào về mặt cảm xúc đúng không? Mình hiểu rằng đôi khi những cảm xúc tiêu cực có thể khiến chúng ta cảm thấy khó khăn và bối rối. \n\nVề mặt cảm xúc, stress có thể hiện ra rất nhiều cách khác nhau, có thể khiến bạn cảm thấy:\n\n*   **Khó chịu:** Cảm giác bực bội, khó chịu, dễ cáu gắt hơn bình thường.\n*   **Lo lắng, căng thẳng:** Luôn cảm thấy bồn chồn, lo lắng về những việc sắp tới hoặc những vấn đề đang gặp phải.\n*   **Buồn bã, chán nản:** Mất hứng thú với những việc mình từng yêu thích, cảm thấy mọi thứ trở nên vô vị.\n*   **Mất giá trị bản thân:** Cảm thấy mình không đủ tốt, không có giá trị, dễ tự ti.\n\nNgoài ra, stress còn có thể khiến bạn dễ nổi nóng, trở nên nóng tính hơn, hoặc thậm chí là cảm thấy mất mát, trống rỗng. \n\nViệc nhận biết những biểu hiện cảm xúc này là bước đầu tiên rất quan trọng để đối diện với stress. Hãy thử dành thời gian lắng nghe cảm xúc của mình, chấp nhận rằng việc cảm thấy tiêu cực là điều bình thường khi phải đối mặt với áp lực.\n\nNếu bạn cảm thấy những cảm xúc này quá mạnh mẽ và ảnh hưởng đến cuộc sống của mình, đừng ngần ngại tìm kiếm sự giúp đỡ từ bạn bè, người thân hoặc chuyên gia tâm lý nhé. Mình luôn ở đây để lắng nghe và hỗ trợ bạn.\n\n**Nếu bạn đang trong tình trạng khủng hoảng hoặc có ý định làm hại bản thân, hãy liên hệ ngay với người thân, bạn bè hoặc chuyên gia tâm lý tại trường. Bạn không đơn độc và có người sẵn sàng giúp đỡ.**',
#   'Chào bạn,\n\nBạn đang thắc mắc về việc stress ảnh hưởng đến hành vi như thế nào đúng không? Đây là một câu hỏi rất hay và quan trọng. Mình hiểu rằng đôi khi stress có thể khiến chúng ta cảm thấy khó khăn trong việc kiểm soát bản thân và hành động theo những cách không mong muốn.\n\nHãy hình dung stress giống như một "cảnh báo" của cơ thể. Khi chúng ta đối mặt với những áp lực, khó khăn (ví dụ như áp lực học tập, các mối quan hệ, hoặc những thay đổi trong cuộc sống), cơ thể sẽ phản ứng bằng cách giải phóng các hormone stress. Điều này giúp chúng ta có thêm năng lượng để đối phó với tình huống đó.\n\nTuy nhiên, nếu stress kéo dài hoặc quá mức, nó có thể tác động tiêu cực đến nhiều khía cạnh trong cuộc sống của bạn, cụ thể như:\n\n*   **Về cảm xúc:** Bạn có thể cảm thấy dễ cáu gắt, lo lắng, buồn bã, thậm chí là mất hứng thú với những điều mình từng yêu thích. Đôi khi, bạn có thể cảm thấy mình không đủ tốt, vô dụng hoặc thất bại.\n*   **Về hành vi:** Stress có thể khiến bạn thay đổi thói quen ăn uống, ngủ nghỉ. Có người lại tìm đến các chất kích thích như rượu, thuốc lá để giải tỏa. Một số người lại trở nên bồn chồn, khó tập trung, hoặc thậm chí là thu mình lại, tránh giao tiếp với mọi người.\n*   **Về học tập:** Stress có thể ảnh hưởng đến khả năng tập trung, ghi nhớ, và làm bài tập. Bạn có thể cảm thấy mất động lực học tập, không còn hứng thú với việc học.\n*   **Về các mối quan hệ:** Stress có thể khiến bạn dễ xung đột với bạn bè, gia đình, hoặc những người xung quanh. Bạn có thể trở nên khó chịu, cáu gắt, hoặc thậm chí là xa lánh mọi người.\n\nĐiều quan trọng là bạn cần nhận biết những dấu hiệu stress đang ảnh hưởng đến mình. Đừng cố gắng gồng mình lên để đối phó một mình. Hãy tìm kiếm sự hỗ trợ từ những người xung quanh, như gia đình, bạn bè, thầy cô, hoặc chuyên gia tâm lý.\n\n**Một vài gợi ý nhỏ có thể giúp bạn đối diện với stress:**\n\n*   **Tìm hiểu nguyên nhân:** Hãy thử xác định xem điều gì đang gây ra stress cho bạn. Khi đã biết nguyên nhân, bạn có thể tìm cách giải quyết hoặc giảm bớt áp lực.\n*   **Chăm sóc bản thân:** Đảm bảo bạn có đủ giấc ngủ, ăn uống đầy đủ, và tập thể dục thường xuyên. Những hoạt động này có thể giúp bạn giảm căng thẳng và cải thiện tâm trạng.\n*   **Tìm kiếm hoạt động thư giãn:** Hãy dành thời gian cho những hoạt động mà bạn yêu thích, như nghe nhạc, đọc sách, xem phim, hoặc đi dạo.\n*   **Chia sẻ với người khác:** Đừng ngại chia sẻ những cảm xúc của bạn với những người bạn tin tưởng. Việc được lắng nghe và thấu hiểu có thể giúp bạn cảm thấy tốt hơn.\n*   **Học cách quản lý thời gian:** Lập kế hoạch học tập và làm việc một cách khoa học để tránh bị quá tải.\n\nNếu bạn cảm thấy quá khó khăn để đối phó với stress, hoặc nếu bạn có những ý nghĩ tiêu cực về bản thân, đừng ngần ngại tìm kiếm sự giúp đỡ từ chuyên gia tâm lý nhé. Họ có thể cung cấp cho bạn những công cụ và kỹ thuật để quản lý stress một cách hiệu quả.\n\n**Nếu em đang trong tình trạng khủng hoảng hoặc có ý định làm hại bản thân, hãy liên hệ ngay với người thân, bạn bè hoặc chuyên gia tâm lý tại trường. Em không đơn độc và có người sẵn sàng giúp đỡ.**\n\nMình luôn ở đây để lắng nghe và hỗ trợ bạn. Hãy nhớ rằng bạn xứng đáng được hạnh phúc và có một cuộc sống khỏe mạnh về tinh thần.',
#   'Chào bạn, câu hỏi của bạn rất hay và cũng là điều mà nhiều người thắc mắc đấy. Mình hiểu rằng đôi khi stress nghe có vẻ tiêu cực, nhưng thực tế nó không phải lúc nào cũng vậy đâu.\n\nHãy tưởng tượng stress giống như một "cảnh báo" từ cơ thể của chúng ta. Khi gặp phải những tình huống mới, khó khăn hoặc áp lực, cơ thể sẽ sản sinh ra stress để giúp chúng ta tập trung hơn, có động lực để đối phó và giải quyết vấn đề. Ví dụ, trước một bài kiểm tra quan trọng, một chút stress có thể giúp bạn ôn tập kỹ hơn và làm bài tốt hơn đấy!\n\nTuy nhiên, vấn đề nằm ở chỗ khi stress trở nên quá mức và kéo dài, hoặc khi chúng ta không có cách nào để giải tỏa nó, thì lúc này stress mới trở nên tiêu cực. Nó có thể ảnh hưởng đến tâm trạng, sức khỏe thể chất và cả các mối quan hệ của bạn. Bạn có thể cảm thấy khó chịu, lo lắng, mất ngủ, hoặc thậm chí là không còn hứng thú với những việc mình từng yêu thích nữa.\n\nVậy làm thế nào để đối diện với stress một cách lành mạnh?\n\n*   **Nhận biết dấu hiệu:** Hãy chú ý đến những thay đổi trong cảm xúc, suy nghĩ và hành vi của mình. Khi cảm thấy căng thẳng, đừng cố gắng phớt lờ nó.\n*   **Tìm hiểu nguyên nhân:** Cố gắng xác định điều gì đang gây ra stress cho bạn. Có thể là áp lực học tập, vấn đề trong gia đình, hoặc những khó khăn trong cuộc sống.\n*   **Tìm cách giải tỏa:** Có rất nhiều cách để giải tỏa stress, như tập thể dục, nghe nhạc, đọc sách, trò chuyện với bạn bè hoặc người thân, hoặc đơn giản là dành thời gian cho những sở thích cá nhân.\n*   **Học cách thư giãn:** Các bài tập thở, thiền, yoga có thể giúp bạn giảm căng thẳng và tìm lại sự bình tĩnh.\n*   **Chia sẻ:** Đừng ngại chia sẻ những khó khăn của mình với người mà bạn tin tưởng. Đôi khi, chỉ cần nói ra những điều mình đang trải qua cũng có thể giúp bạn cảm thấy tốt hơn.\n\nNếu bạn cảm thấy stress đang ảnh hưởng nghiêm trọng đến cuộc sống của mình, đừng ngần ngại tìm kiếm sự giúp đỡ từ chuyên gia tâm lý nhé. Họ có thể cung cấp cho bạn những lời khuyên và hỗ trợ phù hợp.\n\n**Nếu em đang trong tình trạng khủng hoảng hoặc có ý định làm hại bản thân, hãy liên hệ ngay với người thân, bạn bè hoặc chuyên gia tâm lý tại trường. Em không đơn độc và có người sẵn sàng giúp đỡ.**\n\nMình luôn ở đây để lắng nghe và hỗ trợ bạn. Đừng ngần ngại chia sẻ bất cứ điều gì bạn đang gặp phải nhé!'])

# %%
evaluator = client.evals()
evaluator.eval_llm_answer(
    metrics=metrics,
    questions=questions,
    response_llms=response_llms,
    contexts=contexts,
    ground_truths=ground_truths)
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Cell In[39], line 2
#       1 evaluator = client.evals()
# ----> 2 evaluator.eval_llm_answer(
#       3     metrics=metrics,
#       4     questions=questions,
#       5     response_llms=response_llms,
#       6     contexts=contexts,
#       7     ground_truths=ground_truths)
#
# File d:\Docs\UIT\KLTN\llmops-multi-agents\.venv\Lib\site-packages\protonx\evaluator.py:37, in Evaluator.eval_llm_answer(self, metrics, questions, response_llms, ground_truths, contexts, **kwargs)
#      19 def eval_llm_answer(self,
#      20          metrics: Optional[Union[str, List[str]]] = None,
#      21          questions: Optional[Union[str, List[str]]] = None,
#    (...)     25          **kwargs: Any
#      26     ) -> List:
#      28     payload = self._build_payload(
#      29         metrics=metrics,
#      30         questions=questions,
#    (...)     34         **kwargs
#      35     )
# ---> 37     return self._http.post("/eval_llm_answer/", payload)
#
# File d:\Docs\UIT\KLTN\llmops-multi-agents\.venv\Lib\site-packages\protonx\_http.py:51, in HTTPClient.post(self, path, json_body)
#      45     data = resp.json()
#      46     readable = (
#      47         data.get("errors", {})
#      48             .get("server", {})
#      49             .get("readableMsg", resp.text)
#      50     )
# ---> 51     raise APIError(resp.status_code, readable)
#      52 except ValueError:
#      53     raise APIError(resp.status_code, resp.text)
#
# APIError: APIError 429: You have exceeded the daily request limit (10). Please try again later.
